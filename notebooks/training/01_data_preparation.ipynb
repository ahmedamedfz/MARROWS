# %% [markdown]
# # 01 - Data Preparation
#
# This notebook prepares your medical image data for YOLO training.
#
# ## What this notebook does:
# 1. Checks your raw data
# 2. Applies color normalization
# 3. Splits data into training and validation sets
# 4. Creates YOLO-format annotations
#
# ## Before you start:
# - Place your images in `data/raw/your_dataset_name/`
# - Ensure annotations are properly formatted
#
# **Just run each cell by pressing Shift+Enter!** 🚀

# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))

from data_processing.normalizer import batch_color_transfer
from data_processing.data_splitter import split_dataset

print('📊 Data preparation tools loaded successfully!')

# %% [markdown]
# ## Step 1: Check your raw data
#
# Let's see what data you have:

# %%
# Check available datasets
data_path = '../data/raw/'
datasets = [d for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d))]

print('📁 Available datasets:')
for i, dataset in enumerate(datasets):
    print(f'   {i+1}. {dataset}')

print(f'
✅ Found {len(datasets)} datasets ready for processing!')
