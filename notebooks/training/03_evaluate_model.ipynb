# %% [markdown]
# # 03 - Evaluate Model Performance
#
# This notebook evaluates how well your trained model performs.
#
# ## What this notebook shows:
# 1. Training progress charts
# 2. Model accuracy metrics
# 3. Example predictions on test images
# 4. Performance comparison
#
# ## You'll see:
# - 📊 **Charts**: Loss curves and accuracy over time
# - 🎯 **Metrics**: Precision, Recall, F1-score
# - 🖼️ **Examples**: Your model's predictions on real images
# - 📋 **Report**: Summary for your records
#
# **Let's see how your model performed!** 📈

# %%
import sys
sys.path.append('../src')

from evaluation.validator import ModelValidator
from ultralytics import YOLO
import matplotlib.pyplot as plt

print('📊 Model evaluation tools loaded!')
